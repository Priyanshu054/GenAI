# %%
from openai import OpenAI

# %%
import requests
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
response = ollama.chat.completions.create(
    model="llama3.2",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello! How can you assist me today?"},
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Hello! I'm here to help with any questions, topics, or tasks you'd like to discuss. I can assist you in a variety of ways, such as:
#
# * Answering questions on a wide range of subjects, including but not limited to history, science, technology, culture, and more
# * Providing explanations and insights on various topics
# * Offering suggestions and ideas for projects, problem-solving, or creative endeavors
# * Helping with language-related tasks, such as grammar checks, language translation, or writing suggestions
# * Engaging in conversations and discussions on various subjects
# * And more!
#
# What's on your mind today? Do you have a specific question, topic, or goal you'd like to work on? I'm here to help and support you.

# %%
response = ollama.chat.completions.create(
    model="ministral-3:3b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello! How can you assist me today?"},
    ]
)   

print(response.choices[0].message.content)
# Out:
# Hello! I’m here to assist you in any way I can—feel free to ask me anything! Here are a few examples of what I can help with today:
#
# **General Assistance:**
# - Answer questions on a wide range of topics (history, science, philosophy, etc.)
# - Provide explanations, definitions, or summaries of complex ideas
# - Help you solve math problems, coding puzzles, or brain teasers
# - Recommend books, movies, or educational resources
#
# **Productivity & Organization:**
# - Give study tips, time-management advice, or to-do list help
# - Write emails or letters (or review them for you)
# - Draft outlines, reports, or creative work (plots, essays, code snippets)
#
# **Creativity & Learning:**
# - Brainstorm ideas (fictional characters, business concepts, stories)
# - Help with learning new languages, memorizing facts, or improving skills
# - Assist with puzzles like Sudoku, crosswords, or lateral thinking
#
# **Everyday Life & Recommendations:**
# - Suggest travel destinations, recipes, or home projects
# - Help choose the best gadget, tool, or service for specific needs
# - Explain technical, scientific, or medical topics simply
#
# **Specific Needs or Projects in Mind?**
# For example, you could ask:
# - *"How does quantum computing work?"*
# - *"Write a 5-paragraph argument essay against social media privacy concerns."*
# - *"I’m learning Spanish—what’s the best app to test my understanding?"*
# Let me know how your day (or your *potentially* awesome project) is going, and I’m excited to help! 😊

# %%
response = ollama.chat.completions.create(
    model="qwen3.5:4b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello! How can you assist me today?"},
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello there! It's wonderful to meet you. 👋
#
# I'm here to help with a wide variety of tasks. Depending on what you're looking for, I can assist you with:
#
# *   **Information & Answers:** Explaining concepts, checking facts, or providing summaries.
# *   **Content Creation:** Writing stories, emails, reports, social media posts, or creative ideas.
# *   **Development & Tech:** Debugging code, explaining programming concepts, or writing scripts.
# *   **Learning:** Breaking down complex topics into simpler parts or summarizing subjects you're studying.
# *   **Analysis:** Organizing thoughts or giving feedback on your work.
#
# Is there anything specific you are working on right now? Just let me know! 😊
